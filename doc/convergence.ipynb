# %%
import matplotlib.pyplot as plt

# %%
FID = [312.38, 153.15, 100.2, 89.2, 75.49, 68.78, 58.44,
       55.54,50.23,44.44,40.57,36.87,33.12,30.45,26.56,
       23.77,20.90,18.34,16.56,12.23,10.33,8.12,7.23,6.49,6.29]
fig, ax = plt.subplots()
ax.plot(FID, label='FID', color="purple")
ax.plot(FID, color="purple", marker='o')
ax.set_xlabel('Training Epoch') #设置x轴名称 x label
ax.set_ylabel('FID') #设置y轴名称 y label
ax.set_title(" Training Curve of FRDG based on MS_COCO Dataset")
plt.legend()
plt.savefig("convergence.svg", format = "svg")
plt.savefig("convergence.jpg", format = "jpg")
plt.show()
